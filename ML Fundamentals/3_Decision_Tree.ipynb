# %%
# For Google Colaboratory
import sys, os
if 'google.colab' in sys.modules:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/AI_ML_Fundamentals' # Please adjust the path accordingly
    os.chdir(path_to_file)
    # !pwd
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/AI_ML_Fundamentals

# %% [markdown]
# **Load Data**

# %%
import pandas as pd
dataset = pd.read_csv("diabetes.csv")
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X = dataset.drop(['Outcome'], axis =1)
y = dataset.Outcome

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train.shape
# Out:
# (537, 8)

# %%
X_test.shape
# Out:
# (231, 8)

# %% [markdown]
# **Build and Train the Model**

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt
# %matplotlib inline

def decision_tree(d):
  model = DecisionTreeClassifier(max_depth=d, random_state=0)
  model.fit(X_train, y_train)
  plt.figure(figsize=(25,10))
  plot_tree(model,
               feature_names = X_train.columns,
               class_names = ['No', 'Yes'],
               rounded = True,
               filled= True,
               fontsize =20)
  plt.show()

  print('train_acc:', model.score(X_train, y_train),
      '\n test_acc:', model.score(X_test, y_test))

  return model

# %%
decision_tree(d =3)
# Out:
# train_acc: 0.7672253258845437
#  test_acc: 0.7272727272727273
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
decision_tree(d =5)
# Out:
# train_acc: 0.8324022346368715
#  test_acc: 0.7619047619047619
# DecisionTreeClassifier(max_depth=5, random_state=0)

# %%
decision_tree(d =8)
# Out:
# train_acc: 0.9106145251396648
#  test_acc: 0.7445887445887446
# DecisionTreeClassifier(max_depth=8, random_state=0)

# %%
decision_tree(d =10)
# Out:
# train_acc: 0.9608938547486033
#  test_acc: 0.7402597402597403
# DecisionTreeClassifier(max_depth=10, random_state=0)

# %%
decision_tree(d =100)
# Out:
# train_acc: 1.0
#  test_acc: 0.7229437229437229
# DecisionTreeClassifier(max_depth=100, random_state=0)
